# %%
import pandas as pd
import psycopg2

# Database connection parameters
params = {
    "host": "localhost",       # or your server's IP address/domain name
    "port": 5433,             # default postgres port
    "database": "ipek_database",
    "user": "postgres",       # default superuser
    "password": "Arasya123."
}

# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM account"

# Load data into a pandas DataFrame
account = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame
print(account)
# Out:
#                   created_at                 updated_at  is_deleted  \
# 0 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
# 1 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 2 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 3 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 4 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 5 2023-08-03 11:12:14.317763 2023-08-03 11:12:14.317763       False
# 6 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 7 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
#
#   deleted_at                                    id     type  \
# 0       None  1978c662-4cd4-4164-9d1e-0a938a89b43d  DEPOSIT
# 1       None  4c01f230-75ab-4cb8-b83d-8a9214795d40  DEPOSIT
# 2       None  5332798b-523f-4d9a-9c7d-38f5aedfad60  DEPOSIT
# 3       None  683eb2a6-4f9c-4a96-85e0-fa7bf9a7814e   CREDIT
# ...

# %%
account
# Out:
#                   created_at                 updated_at  is_deleted  \
# 0 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
# 1 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 2 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 3 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 4 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 5 2023-08-03 11:12:14.317763 2023-08-03 11:12:14.317763       False
# 6 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 7 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
#
#   deleted_at                                    id     type  \
# 0       None  1978c662-4cd4-4164-9d1e-0a938a89b43d  DEPOSIT
# 1       None  4c01f230-75ab-4cb8-b83d-8a9214795d40  DEPOSIT
# 2       None  5332798b-523f-4d9a-9c7d-38f5aedfad60  DEPOSIT
# 3       None  683eb2a6-4f9c-4a96-85e0-fa7bf9a7814e   CREDIT
# ...

# %%
# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction"

# Load data into a pandas DataFrame
transaction = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
transaction
# Out:
#                      created_at                 updated_at  is_deleted  \
# 0    2023-07-26 18:36:14.550089 2023-07-26 18:36:14.550089       False
# 1    2023-07-26 18:36:28.244705 2023-07-26 18:36:28.244705       False
# 2    2023-07-26 18:36:20.091959 2023-07-26 18:36:20.091959       False
# 3    2023-07-26 18:36:28.854304 2023-07-26 18:36:28.854304       False
# 4    2023-07-26 18:36:29.413804 2023-07-26 18:36:29.413804       False
# ...                         ...                        ...         ...
# 3085 2023-07-26 18:36:21.499517 2023-07-26 18:36:21.499517       False
# 3086 2023-07-26 18:36:25.415124 2023-07-26 18:36:25.415124       False
# 3087 2023-08-02 08:05:38.277226 2023-08-02 08:05:38.277226       False
# 3088 2023-07-26 18:36:29.142763 2023-07-26 18:36:29.142763       False
# 3089 2023-07-26 18:36:20.488998 2023-07-26 18:36:20.488998       False
#
#      deleted_at                                    id  \
# 0           NaT  0001378f-f744-4eb0-8b7b-867135071625
# ...

# %%
# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM account_subtype"

# Load data into a pandas DataFrame
account_subtype = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction_subtype"

# Load data into a pandas DataFrame
transaction_subtype = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction_type"

# Load data into a pandas DataFrame
transaction_type = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
# Create a connection
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction_location"

# Load data into a pandas DataFrame
transaction_location = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction_category"

# Load data into a pandas DataFrame
transaction_category = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM transaction_category_association"

# Load data into a pandas DataFrame
transaction_category_association = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# Print the DataFrame

# %%
conn = psycopg2.connect(**params)

# Define your query
sql_query = "SELECT * FROM financial_institution"

# Load data into a pandas DataFrame
financial_institution = pd.read_sql_query(sql_query, conn)

# Close the connection
conn.close()

# %%
# !pip install openpyxl
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\pc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\pc\anaconda3\lib\site-packages)

# %%
account.to_pickle('C:/Users/Pc/Documents/ipek_account_data/account.pkl')

# %%
transaction_subtype.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction_subtype.pkl')

# %%
account_subtype.to_pickle('C:/Users/Pc/Documents/ipek_account_data/account_subtype.pkl')

# %%
transaction_type.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction_type.pkl')

# %%
transaction_location.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction_location.pkl')

# %%
transaction_category.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction_category.pkl')

# %%
transaction_category_association.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction_category_association.pkl')

# %%
financial_institution.to_pickle('C:/Users/Pc/Documents/ipek_account_data/financial_institution.pkl')

# %%
transaction.to_pickle('C:/Users/Pc/Documents/ipek_account_data/transaction.pkl')

# %%
transactions
# Out:
#                      created_at                 updated_at  is_deleted  \
# 0    2023-07-26 18:36:14.550089 2023-07-26 18:36:14.550089       False
# 1    2023-07-26 18:36:28.244705 2023-07-26 18:36:28.244705       False
# 2    2023-07-26 18:36:20.091959 2023-07-26 18:36:20.091959       False
# 3    2023-07-26 18:36:28.854304 2023-07-26 18:36:28.854304       False
# 4    2023-07-26 18:36:29.413804 2023-07-26 18:36:29.413804       False
# ...                         ...                        ...         ...
# 3085 2023-07-26 18:36:21.499517 2023-07-26 18:36:21.499517       False
# 3086 2023-07-26 18:36:25.415124 2023-07-26 18:36:25.415124       False
# 3087 2023-08-02 08:05:38.277226 2023-08-02 08:05:38.277226       False
# 3088 2023-07-26 18:36:29.142763 2023-07-26 18:36:29.142763       False
# 3089 2023-07-26 18:36:20.488998 2023-07-26 18:36:20.488998       False
#
#      deleted_at                                    id  \
# 0           NaT  0001378f-f744-4eb0-8b7b-867135071625
# ...

# %%
account
# Out:
#                   created_at                 updated_at  is_deleted  \
# 0 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
# 1 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 2 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 3 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 4 2023-07-27 04:39:57.678383 2023-08-03 08:05:41.316470       False
# 5 2023-08-03 11:12:14.317763 2023-08-03 11:12:14.317763       False
# 6 2023-07-26 18:36:12.562229 2023-08-03 08:05:33.300269       False
# 7 2023-07-27 04:41:04.803048 2023-08-03 08:05:36.111597       False
#
#   deleted_at                                    id     type  \
# 0       None  1978c662-4cd4-4164-9d1e-0a938a89b43d  DEPOSIT
# 1       None  4c01f230-75ab-4cb8-b83d-8a9214795d40  DEPOSIT
# 2       None  5332798b-523f-4d9a-9c7d-38f5aedfad60  DEPOSIT
# 3       None  683eb2a6-4f9c-4a96-85e0-fa7bf9a7814e   CREDIT
# ...
